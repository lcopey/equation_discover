# %%
import sys
from typing import Literal

import numpy as np
import pandas as pd
import plotly.figure_factory as ff
import plotly.graph_objects as go
import tensorflow as tf
import tensorflow_probability as tfp
from plotly.colors import DEFAULT_PLOTLY_COLORS as colors
from tensorflow.keras.layers import GRU, Dense, Embedding, SimpleRNN, StringLookup
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop

# %load_ext autoreload
# %autoreload 2

sys.path.append("../")
from equation_discover import *
# Out:
# 2023-12-29 22:53:49.377628: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X = pd.DataFrame(np.linspace(-2 * np.pi, 2 * np.pi), columns=["var_x"])
y = np.sin((X * 2 + 1).squeeze())

sampler = RNNSampler(BASE_TOKENS, 16, 1)
regressor = SymbolicRegressor(sampler, SymbolicLoss(), n_samples=12)
optimizer = RMSprop(learning_rate=1e-3)
x = pandas_to_tensor(X)
y = pandas_to_tensor(y)
# Out:
# root - DEBUG - 29-Dec-23 23:04:40 - Initial call, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:41 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (1, 10)
# [[0.11, 0.09, ..., 0.05, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:41 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (1, 10)
# [[0.11, 0.09, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:41 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (1, 10)
# [[0.13, 0.10, ..., 0.00, 0.00]]>

# %%
def train_step(regressor: SymbolicRegressor, x, y):
    with tf.GradientTape() as tape:
        outputs = regressor({"X": x, "y": y})
        loss = regressor.loss_func(y, outputs)
    outputs.rewards = rsquared(y, outputs.y)
    trainable_variables = regressor.sampler.variables
    grads = tape.gradient(loss, trainable_variables)
    optimizer.apply_gradients(zip(grads, trainable_variables))
    return outputs

# %%
rewards = []
for _ in range(10):
    results = train_step(regressor, x, y)
    if any([tf.math.is_nan(result) for result in results.rewards]):
        print('early break')
        break
    rewards.append(results.rewards)
# Out:
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 0, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.09, ..., 0.05, 0.10]
#  [0.11, 0.09, ..., 0.05, 0.10]
#  ...
#  [0.11, 0.09, ..., 0.05, 0.10]
#  [0.11, 0.09, ..., 0.05, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.09, ..., 0.00, 0.00]
#  [0.11, 0.09, ..., 0.00, 0.00]
#  ...
#  [0.11, 0.09, ..., 0.00, 0.00]
#  [0.11, 0.09, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.13, 0.10, ..., 0.00, 0.00]
#  [0.13, 0.10, ..., 0.00, 0.00]
#  ...
#  [0.13, 0.10, ..., 0.00, 0.00]
#  [0.13, 0.10, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 1, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.11, ..., 0.17, 0.06]
#  [0.07, 0.13, ..., 0.16, 0.06]
#  ...
#  [0.07, 0.11, ..., 0.17, 0.06]
#  [0.09, 0.11, ..., 0.17, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.11, ..., 0.00, 0.06]
#  [0.07, 0.13, ..., 0.00, 0.06]
#  ...
#  [0.07, 0.11, ..., 0.00, 0.06]
#  [0.09, 0.11, ..., 0.00, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.13, ..., 0.00, 0.08]
#  [0.09, 0.16, ..., 0.00, 0.07]
#  ...
#  [0.08, 0.13, ..., 0.00, 0.08]
#  [0.11, 0.13, ..., 0.00, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 2, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.11, ..., 0.07, 0.09]
#  [0.09, 0.14, ..., 0.07, 0.09]
#  ...
#  [0.07, 0.13, ..., 0.07, 0.10]
#  [0.06, 0.11, ..., 0.04, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.11, ..., 0.00, 0.09]
#  [0.09, 0.14, ..., 0.07, 0.09]
#  ...
#  [0.07, 0.13, ..., 0.00, 0.10]
#  [0.06, 0.11, ..., 0.04, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.11, ..., 0.00, 0.10]
#  [0.09, 0.14, ..., 0.07, 0.09]
#  ...
#  [0.07, 0.14, ..., 0.00, 0.10]
#  [0.06, 0.11, ..., 0.04, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 3, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.08, ..., 0.21, 0.07]
#  [0.11, 0.09, ..., 0.16, 0.07]
#  ...
#  [0.15, 0.09, ..., 0.19, 0.07]
#  [0.12, 0.08, ..., 0.20, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.08, ..., 0.21, 0.07]
#  [0.11, 0.09, ..., 0.16, 0.07]
#  ...
#  [0.15, 0.09, ..., 0.19, 0.07]
#  [0.12, 0.08, ..., 0.20, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.08, ..., 0.21, 0.07]
#  [0.11, 0.09, ..., 0.16, 0.07]
#  ...
#  [0.15, 0.09, ..., 0.19, 0.07]
#  [0.12, 0.08, ..., 0.20, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 4, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.13, 0.04, ..., 0.09, 0.18]
#  [0.13, 0.05, ..., 0.11, 0.13]
#  ...
#  [0.10, 0.07, ..., 0.09, 0.14]
#  [0.14, 0.06, ..., 0.15, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.13, 0.04, ..., 0.09, 0.18]
#  [0.13, 0.05, ..., 0.11, 0.13]
#  ...
#  [0.10, 0.07, ..., 0.09, 0.14]
#  [0.14, 0.06, ..., 0.15, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.13, 0.04, ..., 0.09, 0.18]
#  [0.13, 0.05, ..., 0.11, 0.13]
#  ...
#  [0.10, 0.07, ..., 0.09, 0.14]
#  [0.14, 0.06, ..., 0.15, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 5, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.11, ..., 0.05, 0.18]
#  [0.05, 0.10, ..., 0.04, 0.16]
#  ...
#  [0.08, 0.13, ..., 0.08, 0.13]
#  [0.05, 0.12, ..., 0.04, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.11, ..., 0.05, 0.18]
#  [0.05, 0.10, ..., 0.04, 0.16]
#  ...
#  [0.08, 0.13, ..., 0.08, 0.13]
#  [0.05, 0.12, ..., 0.04, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.11, ..., 0.05, 0.18]
#  [0.05, 0.10, ..., 0.04, 0.16]
#  ...
#  [0.08, 0.13, ..., 0.08, 0.13]
#  [0.05, 0.12, ..., 0.04, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 6, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.16, 0.08, ..., 0.13, 0.09]
#  [0.17, 0.09, ..., 0.18, 0.09]
#  ...
#  [0.25, 0.03, ..., 0.11, 0.10]
#  [0.16, 0.08, ..., 0.14, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.16, 0.08, ..., 0.13, 0.09]
#  [0.17, 0.09, ..., 0.18, 0.09]
#  ...
#  [0.25, 0.03, ..., 0.11, 0.10]
#  [0.16, 0.08, ..., 0.14, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.16, 0.08, ..., 0.13, 0.09]
#  [0.17, 0.09, ..., 0.18, 0.09]
#  ...
#  [0.25, 0.03, ..., 0.11, 0.10]
#  [0.16, 0.08, ..., 0.14, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 7, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.20, 0.05, ..., 0.11, 0.06]
#  [0.15, 0.07, ..., 0.07, 0.06]
#  ...
#  [0.05, 0.12, ..., 0.05, 0.13]
#  [0.06, 0.17, ..., 0.07, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.20, 0.05, ..., 0.11, 0.06]
#  [0.15, 0.07, ..., 0.07, 0.06]
#  ...
#  [0.05, 0.12, ..., 0.05, 0.13]
#  [0.06, 0.17, ..., 0.07, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.20, 0.05, ..., 0.11, 0.06]
#  [0.15, 0.07, ..., 0.07, 0.06]
#  ...
#  [0.05, 0.12, ..., 0.05, 0.13]
#  [0.06, 0.17, ..., 0.07, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 8, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.04, 0.12, ..., 0.05, 0.12]
#  [0.08, 0.12, ..., 0.11, 0.10]
#  ...
#  [0.08, 0.11, ..., 0.07, 0.09]
#  [0.16, 0.10, ..., 0.12, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.04, 0.12, ..., 0.05, 0.12]
#  [0.08, 0.12, ..., 0.11, 0.10]
#  ...
#  [0.08, 0.11, ..., 0.07, 0.09]
#  [0.16, 0.10, ..., 0.12, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.04, 0.12, ..., 0.05, 0.12]
#  [0.08, 0.12, ..., 0.11, 0.10]
#  ...
#  [0.08, 0.11, ..., 0.07, 0.09]
#  [0.16, 0.10, ..., 0.12, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 9, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.09, ..., 0.15, 0.08]
#  [0.09, 0.07, ..., 0.11, 0.08]
#  ...
#  [0.19, 0.06, ..., 0.21, 0.03]
#  [0.07, 0.10, ..., 0.07, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.09, ..., 0.15, 0.08]
#  [0.09, 0.07, ..., 0.11, 0.08]
#  ...
#  [0.00, 0.00, ..., 0.21, 0.03]
#  [0.07, 0.10, ..., 0.07, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.09, ..., 0.15, 0.08]
#  [0.09, 0.07, ..., 0.11, 0.08]
#  ...
#  [0.00, 0.00, ..., 0.87, 0.13]
#  [0.07, 0.10, ..., 0.07, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 10, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.15, 0.07, ..., 0.20, 0.12]
#  [0.10, 0.08, ..., 0.13, 0.09]
#  ...
#  [0.08, 0.07, ..., 0.07, 0.16]
#  [0.05, 0.19, ..., 0.06, 0.11]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.15, 0.07, ..., 0.20, 0.12]
#  [0.10, 0.08, ..., 0.13, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.07, 0.16]
#  [0.05, 0.19, ..., 0.06, 0.11]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.15, 0.07, ..., 0.20, 0.12]
#  [0.10, 0.08, ..., 0.13, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.32, 0.68]
#  [0.05, 0.19, ..., 0.06, 0.11]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 11, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.10, ..., 0.10, 0.18]
#  [0.11, 0.06, ..., 0.19, 0.09]
#  ...
#  [0.06, 0.04, ..., 0.04, 0.14]
#  [0.17, 0.11, ..., 0.17, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.10, 0.18]
#  [0.11, 0.06, ..., 0.19, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.04, 0.14]
#  [0.00, 0.00, ..., 0.17, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.37, 0.63]
#  [0.11, 0.06, ..., 0.19, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.21, 0.79]
#  [0.00, 0.00, ..., 0.79, 0.21]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 12, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.11, ..., 0.07, 0.15]
#  [0.13, 0.06, ..., 0.09, 0.13]
#  ...
#  [0.08, 0.07, ..., 0.08, 0.17]
#  [0.10, 0.08, ..., 0.11, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.07, 0.15]
#  [0.00, 0.00, ..., 0.09, 0.13]
#  ...
#  [0.00, 0.00, ..., 0.08, 0.17]
#  [0.00, 0.00, ..., 0.11, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.31, 0.69]
#  [0.00, 0.00, ..., 0.42, 0.58]
#  ...
#  [0.00, 0.00, ..., 0.32, 0.68]
#  [0.00, 0.00, ..., 0.44, 0.56]]>
# root - DEBUG - 29-Dec-23 23:04:42 - Sampling token iteration 13, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:42 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.14, ..., 0.18, 0.10]
#  [0.13, 0.12, ..., 0.14, 0.07]
#  ...
#  [0.12, 0.16, ..., 0.05, 0.09]
#  [0.09, 0.08, ..., 0.07, 0.18]]>
# root - DEBUG - 29-Dec-23 23:04:42 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.18, 0.10]
#  [0.00, 0.00, ..., 0.14, 0.07]
#  ...
#  [0.00, 0.00, ..., 0.05, 0.09]
#  [0.00, 0.00, ..., 0.07, 0.18]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.65, 0.35]
#  [0.00, 0.00, ..., 0.66, 0.34]
#  ...
#  [0.00, 0.00, ..., 0.35, 0.65]
#  [0.00, 0.00, ..., 0.26, 0.74]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 14, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.08, ..., 0.09, 0.17]
#  [0.13, 0.06, ..., 0.12, 0.09]
#  ...
#  [0.22, 0.10, ..., 0.15, 0.05]
#  [0.13, 0.07, ..., 0.11, 0.11]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.09, 0.17]
#  [0.00, 0.00, ..., 0.12, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.15, 0.05]
#  [0.00, 0.00, ..., 0.11, 0.11]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.34, 0.66]
#  [0.00, 0.00, ..., 0.58, 0.42]
#  ...
#  [0.00, 0.00, ..., 0.73, 0.27]
#  [0.00, 0.00, ..., 0.49, 0.51]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Debugging, object=SymbolicLoss, rewards=tf.Tensor(
# [0.58211213 0.01164853 0.         0.32887483 0.6278294  0.5896761
#  0.6418639  0.46759215 0.05056982 0.55055565 0.54626274 0.48419815], shape=(12,), dtype=float32), threshold=0.6240140438079834, mask=tf.Tensor([False False False False  True False  True False False False False False], shape=(12,), dtype=bool)
# root - DEBUG - 29-Dec-23 23:04:43 - Debugging, object=SymbolicLoss, risk_seeking=tf.Tensor(-0.2521262, shape=(), dtype=float32), entropy_loss=tf.Tensor(22.751926, shape=(), dtype=float32)
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 0, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.08, ..., 0.05, 0.09]
#  [0.11, 0.08, ..., 0.05, 0.09]
#  ...
#  [0.11, 0.08, ..., 0.05, 0.09]
#  [0.11, 0.08, ..., 0.05, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.08, ..., 0.00, 0.00]
#  [0.11, 0.08, ..., 0.00, 0.00]
#  ...
#  [0.11, 0.08, ..., 0.00, 0.00]
#  [0.11, 0.08, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.13, 0.09, ..., 0.00, 0.00]
#  [0.13, 0.09, ..., 0.00, 0.00]
#  ...
#  [0.13, 0.09, ..., 0.00, 0.00]
#  [0.13, 0.09, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 1, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.11, ..., 0.18, 0.06]
#  [0.09, 0.10, ..., 0.19, 0.06]
#  ...
#  [0.09, 0.10, ..., 0.19, 0.06]
#  [0.09, 0.10, ..., 0.19, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.11, ..., 0.00, 0.06]
#  [0.09, 0.10, ..., 0.00, 0.06]
#  ...
#  [0.09, 0.10, ..., 0.00, 0.06]
#  [0.09, 0.10, ..., 0.00, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.13, ..., 0.00, 0.07]
#  [0.11, 0.13, ..., 0.00, 0.07]
#  ...
#  [0.11, 0.13, ..., 0.00, 0.07]
#  [0.11, 0.13, ..., 0.00, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 2, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.10, ..., 0.06, 0.09]
#  [0.05, 0.12, ..., 0.04, 0.09]
#  ...
#  [0.06, 0.09, ..., 0.04, 0.07]
#  [0.08, 0.13, ..., 0.06, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.10, ..., 0.06, 0.09]
#  [0.05, 0.12, ..., 0.00, 0.09]
#  ...
#  [0.06, 0.09, ..., 0.04, 0.07]
#  [0.08, 0.13, ..., 0.06, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.10, ..., 0.06, 0.09]
#  [0.05, 0.13, ..., 0.00, 0.09]
#  ...
#  [0.06, 0.09, ..., 0.04, 0.07]
#  [0.08, 0.13, ..., 0.06, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 3, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.11, ..., 0.21, 0.05]
#  [0.09, 0.13, ..., 0.20, 0.06]
#  ...
#  [0.10, 0.11, ..., 0.29, 0.04]
#  [0.13, 0.11, ..., 0.24, 0.02]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.11, ..., 0.21, 0.05]
#  [0.09, 0.13, ..., 0.00, 0.06]
#  ...
#  [0.10, 0.11, ..., 0.29, 0.04]
#  [0.13, 0.11, ..., 0.24, 0.02]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.11, ..., 0.21, 0.05]
#  [0.12, 0.17, ..., 0.00, 0.07]
#  ...
#  [0.10, 0.11, ..., 0.29, 0.04]
#  [0.13, 0.11, ..., 0.24, 0.02]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 4, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.07, ..., 0.12, 0.11]
#  [0.15, 0.09, ..., 0.14, 0.10]
#  ...
#  [0.16, 0.06, ..., 0.14, 0.10]
#  [0.12, 0.07, ..., 0.09, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.07, ..., 0.12, 0.11]
#  [0.15, 0.09, ..., 0.00, 0.10]
#  ...
#  [0.16, 0.06, ..., 0.14, 0.10]
#  [0.12, 0.07, ..., 0.09, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.07, ..., 0.12, 0.11]
#  [0.18, 0.11, ..., 0.00, 0.12]
#  ...
#  [0.16, 0.06, ..., 0.14, 0.10]
#  [0.12, 0.07, ..., 0.09, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 5, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.05, 0.10, ..., 0.05, 0.16]
#  [0.07, 0.09, ..., 0.03, 0.14]
#  ...
#  [0.09, 0.10, ..., 0.04, 0.10]
#  [0.04, 0.10, ..., 0.06, 0.13]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.05, 0.10, ..., 0.05, 0.16]
#  [0.07, 0.09, ..., 0.00, 0.14]
#  ...
#  [0.09, 0.10, ..., 0.04, 0.10]
#  [0.04, 0.10, ..., 0.06, 0.13]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.05, 0.10, ..., 0.05, 0.16]
#  [0.08, 0.09, ..., 0.00, 0.14]
#  ...
#  [0.09, 0.10, ..., 0.04, 0.10]
#  [0.04, 0.10, ..., 0.06, 0.13]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 6, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.15, 0.07, ..., 0.18, 0.09]
#  [0.08, 0.10, ..., 0.11, 0.09]
#  ...
#  [0.11, 0.08, ..., 0.12, 0.09]
#  [0.17, 0.07, ..., 0.08, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.15, 0.07, ..., 0.18, 0.09]
#  [0.08, 0.10, ..., 0.00, 0.09]
#  ...
#  [0.11, 0.08, ..., 0.12, 0.09]
#  [0.17, 0.07, ..., 0.08, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.15, 0.07, ..., 0.18, 0.09]
#  [0.09, 0.11, ..., 0.00, 0.10]
#  ...
#  [0.11, 0.08, ..., 0.12, 0.09]
#  [0.17, 0.07, ..., 0.08, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 7, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.11, ..., 0.07, 0.05]
#  [0.05, 0.16, ..., 0.08, 0.06]
#  ...
#  [0.08, 0.09, ..., 0.07, 0.07]
#  [0.12, 0.12, ..., 0.15, 0.02]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.11, ..., 0.07, 0.05]
#  [0.05, 0.16, ..., 0.08, 0.06]
#  ...
#  [0.08, 0.09, ..., 0.07, 0.07]
#  [0.12, 0.12, ..., 0.15, 0.02]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.11, ..., 0.07, 0.05]
#  [0.05, 0.16, ..., 0.08, 0.06]
#  ...
#  [0.08, 0.09, ..., 0.07, 0.07]
#  [0.12, 0.12, ..., 0.15, 0.02]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 8, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.08, ..., 0.13, 0.05]
#  [0.12, 0.09, ..., 0.12, 0.08]
#  ...
#  [0.07, 0.07, ..., 0.08, 0.10]
#  [0.13, 0.07, ..., 0.10, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.08, ..., 0.13, 0.05]
#  [0.12, 0.09, ..., 0.12, 0.08]
#  ...
#  [0.07, 0.07, ..., 0.08, 0.10]
#  [0.13, 0.07, ..., 0.10, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.08, ..., 0.13, 0.05]
#  [0.12, 0.09, ..., 0.12, 0.08]
#  ...
#  [0.07, 0.07, ..., 0.08, 0.10]
#  [0.13, 0.07, ..., 0.10, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 9, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.08, ..., 0.12, 0.04]
#  [0.07, 0.11, ..., 0.11, 0.10]
#  ...
#  [0.08, 0.09, ..., 0.15, 0.08]
#  [0.03, 0.08, ..., 0.05, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.08, ..., 0.12, 0.04]
#  [0.07, 0.11, ..., 0.11, 0.10]
#  ...
#  [0.08, 0.09, ..., 0.15, 0.08]
#  [0.03, 0.08, ..., 0.05, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.08, ..., 0.12, 0.04]
#  [0.07, 0.11, ..., 0.11, 0.10]
#  ...
#  [0.08, 0.09, ..., 0.15, 0.08]
#  [0.03, 0.08, ..., 0.05, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 10, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.05, ..., 0.07, 0.08]
#  [0.06, 0.12, ..., 0.06, 0.15]
#  ...
#  [0.11, 0.11, ..., 0.08, 0.11]
#  [0.09, 0.08, ..., 0.13, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.05, ..., 0.07, 0.08]
#  [0.06, 0.12, ..., 0.06, 0.15]
#  ...
#  [0.00, 0.00, ..., 0.08, 0.11]
#  [0.09, 0.08, ..., 0.13, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.05, ..., 0.07, 0.08]
#  [0.06, 0.12, ..., 0.06, 0.15]
#  ...
#  [0.00, 0.00, ..., 0.42, 0.58]
#  [0.09, 0.08, ..., 0.13, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 11, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.03, ..., 0.09, 0.12]
#  [0.16, 0.07, ..., 0.21, 0.08]
#  ...
#  [0.13, 0.08, ..., 0.20, 0.08]
#  [0.15, 0.12, ..., 0.12, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.03, ..., 0.09, 0.12]
#  [0.16, 0.07, ..., 0.21, 0.08]
#  ...
#  [0.00, 0.00, ..., 0.20, 0.08]
#  [0.00, 0.00, ..., 0.12, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.03, ..., 0.09, 0.12]
#  [0.16, 0.07, ..., 0.21, 0.08]
#  ...
#  [0.00, 0.00, ..., 0.71, 0.29]
#  [0.00, 0.00, ..., 0.62, 0.38]]>
# root - DEBUG - 29-Dec-23 23:04:43 - Sampling token iteration 12, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:43 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.05, 0.06, ..., 0.04, 0.17]
#  [0.09, 0.11, ..., 0.06, 0.18]
#  ...
#  [0.06, 0.09, ..., 0.05, 0.16]
#  [0.16, 0.10, ..., 0.13, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.04, 0.17]
#  [0.00, 0.00, ..., 0.06, 0.18]
#  ...
#  [0.00, 0.00, ..., 0.05, 0.16]
#  [0.00, 0.00, ..., 0.13, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:43 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.19, 0.81]
#  [0.00, 0.00, ..., 0.25, 0.75]
#  ...
#  [0.00, 0.00, ..., 0.25, 0.75]
#  [0.00, 0.00, ..., 0.67, 0.33]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 13, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.15, 0.10, ..., 0.20, 0.07]
#  [0.06, 0.19, ..., 0.07, 0.13]
#  ...
#  [0.10, 0.12, ..., 0.09, 0.07]
#  [0.06, 0.11, ..., 0.08, 0.04]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.20, 0.07]
#  [0.00, 0.00, ..., 0.07, 0.13]
#  ...
#  [0.00, 0.00, ..., 0.09, 0.07]
#  [0.00, 0.00, ..., 0.08, 0.04]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.74, 0.26]
#  [0.00, 0.00, ..., 0.35, 0.65]
#  ...
#  [0.00, 0.00, ..., 0.56, 0.44]
#  [0.00, 0.00, ..., 0.64, 0.36]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 14, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.21, 0.07, ..., 0.19, 0.07]
#  [0.26, 0.09, ..., 0.15, 0.08]
#  ...
#  [0.11, 0.10, ..., 0.25, 0.07]
#  [0.09, 0.08, ..., 0.09, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.19, 0.07]
#  [0.00, 0.00, ..., 0.15, 0.08]
#  ...
#  [0.00, 0.00, ..., 0.25, 0.07]
#  [0.00, 0.00, ..., 0.09, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.72, 0.28]
#  [0.00, 0.00, ..., 0.65, 0.35]
#  ...
#  [0.00, 0.00, ..., 0.78, 0.22]
#  [0.00, 0.00, ..., 0.52, 0.48]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Debugging, object=SymbolicLoss, rewards=tf.Tensor(
# [0.5872371  0.40406224 0.5380537  0.66488487 0.5805073  0.6054219
#  0.48419815 0.1833122  0.0717953  0.57737935 0.3625223  0.3040222 ], shape=(12,), dtype=float32), threshold=0.6036034226417542, mask=tf.Tensor([False False False  True False  True False False False False False False], shape=(12,), dtype=bool)
# root - DEBUG - 29-Dec-23 23:04:44 - Debugging, object=SymbolicLoss, risk_seeking=tf.Tensor(-0.7738815, shape=(), dtype=float32), entropy_loss=tf.Tensor(15.329184, shape=(), dtype=float32)
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 0, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.08, ..., 0.05, 0.09]
#  [0.11, 0.08, ..., 0.05, 0.09]
#  ...
#  [0.11, 0.08, ..., 0.05, 0.09]
#  [0.11, 0.08, ..., 0.05, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.08, ..., 0.00, 0.00]
#  [0.11, 0.08, ..., 0.00, 0.00]
#  ...
#  [0.11, 0.08, ..., 0.00, 0.00]
#  [0.11, 0.08, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.13, 0.09, ..., 0.00, 0.00]
#  [0.13, 0.09, ..., 0.00, 0.00]
#  ...
#  [0.13, 0.09, ..., 0.00, 0.00]
#  [0.13, 0.09, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 1, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.10, ..., 0.20, 0.06]
#  [0.08, 0.11, ..., 0.19, 0.06]
#  ...
#  [0.09, 0.10, ..., 0.20, 0.05]
#  [0.07, 0.10, ..., 0.20, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.10, ..., 0.20, 0.06]
#  [0.08, 0.11, ..., 0.00, 0.06]
#  ...
#  [0.09, 0.10, ..., 0.00, 0.05]
#  [0.07, 0.10, ..., 0.20, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.10, ..., 0.20, 0.06]
#  [0.10, 0.13, ..., 0.00, 0.08]
#  ...
#  [0.11, 0.13, ..., 0.00, 0.07]
#  [0.07, 0.10, ..., 0.20, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 2, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.08, ..., 0.06, 0.10]
#  [0.08, 0.10, ..., 0.04, 0.11]
#  ...
#  [0.08, 0.08, ..., 0.04, 0.09]
#  [0.09, 0.10, ..., 0.07, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.08, ..., 0.06, 0.10]
#  [0.08, 0.10, ..., 0.00, 0.11]
#  ...
#  [0.08, 0.08, ..., 0.04, 0.09]
#  [0.09, 0.10, ..., 0.07, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.08, ..., 0.06, 0.10]
#  [0.08, 0.10, ..., 0.00, 0.11]
#  ...
#  [0.08, 0.08, ..., 0.04, 0.09]
#  [0.09, 0.10, ..., 0.07, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 3, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.10, ..., 0.20, 0.09]
#  [0.06, 0.11, ..., 0.12, 0.06]
#  ...
#  [0.10, 0.06, ..., 0.17, 0.06]
#  [0.06, 0.07, ..., 0.09, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.10, ..., 0.20, 0.09]
#  [0.06, 0.11, ..., 0.12, 0.06]
#  ...
#  [0.10, 0.06, ..., 0.17, 0.06]
#  [0.06, 0.07, ..., 0.00, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.10, ..., 0.20, 0.09]
#  [0.06, 0.11, ..., 0.12, 0.06]
#  ...
#  [0.10, 0.06, ..., 0.17, 0.06]
#  [0.07, 0.07, ..., 0.00, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 4, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.04, ..., 0.11, 0.14]
#  [0.11, 0.07, ..., 0.19, 0.09]
#  ...
#  [0.08, 0.07, ..., 0.10, 0.17]
#  [0.11, 0.07, ..., 0.22, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.04, ..., 0.11, 0.14]
#  [0.11, 0.07, ..., 0.19, 0.09]
#  ...
#  [0.08, 0.07, ..., 0.10, 0.17]
#  [0.11, 0.07, ..., 0.22, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.04, ..., 0.11, 0.14]
#  [0.11, 0.07, ..., 0.19, 0.09]
#  ...
#  [0.08, 0.07, ..., 0.10, 0.17]
#  [0.11, 0.07, ..., 0.22, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 5, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.07, ..., 0.09, 0.13]
#  [0.08, 0.10, ..., 0.07, 0.15]
#  ...
#  [0.15, 0.11, ..., 0.07, 0.15]
#  [0.17, 0.05, ..., 0.06, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.07, ..., 0.00, 0.13]
#  [0.08, 0.10, ..., 0.07, 0.15]
#  ...
#  [0.15, 0.11, ..., 0.07, 0.15]
#  [0.17, 0.05, ..., 0.06, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.08, ..., 0.00, 0.14]
#  [0.08, 0.10, ..., 0.07, 0.15]
#  ...
#  [0.15, 0.11, ..., 0.07, 0.15]
#  [0.17, 0.05, ..., 0.06, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 6, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.07, ..., 0.17, 0.15]
#  [0.14, 0.06, ..., 0.15, 0.11]
#  ...
#  [0.16, 0.08, ..., 0.13, 0.07]
#  [0.10, 0.04, ..., 0.09, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.07, ..., 0.00, 0.15]
#  [0.14, 0.06, ..., 0.15, 0.11]
#  ...
#  [0.16, 0.08, ..., 0.13, 0.07]
#  [0.10, 0.04, ..., 0.09, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.13, 0.09, ..., 0.00, 0.18]
#  [0.14, 0.06, ..., 0.15, 0.11]
#  ...
#  [0.16, 0.08, ..., 0.13, 0.07]
#  [0.10, 0.04, ..., 0.09, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 7, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.22, 0.07, ..., 0.10, 0.13]
#  [0.09, 0.09, ..., 0.11, 0.10]
#  ...
#  [0.07, 0.16, ..., 0.04, 0.07]
#  [0.06, 0.12, ..., 0.07, 0.11]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.22, 0.07, ..., 0.10, 0.13]
#  [0.09, 0.09, ..., 0.11, 0.10]
#  ...
#  [0.07, 0.16, ..., 0.04, 0.07]
#  [0.06, 0.12, ..., 0.07, 0.11]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.22, 0.07, ..., 0.10, 0.13]
#  [0.09, 0.09, ..., 0.11, 0.10]
#  ...
#  [0.07, 0.16, ..., 0.04, 0.07]
#  [0.06, 0.12, ..., 0.07, 0.11]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 8, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.10, ..., 0.11, 0.14]
#  [0.17, 0.06, ..., 0.16, 0.12]
#  ...
#  [0.12, 0.13, ..., 0.17, 0.04]
#  [0.16, 0.13, ..., 0.11, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.10, ..., 0.11, 0.14]
#  [0.17, 0.06, ..., 0.16, 0.12]
#  ...
#  [0.12, 0.13, ..., 0.17, 0.04]
#  [0.16, 0.13, ..., 0.11, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.10, ..., 0.11, 0.14]
#  [0.17, 0.06, ..., 0.16, 0.12]
#  ...
#  [0.12, 0.13, ..., 0.17, 0.04]
#  [0.16, 0.13, ..., 0.11, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 9, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:44 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.09, ..., 0.07, 0.11]
#  [0.16, 0.03, ..., 0.11, 0.14]
#  ...
#  [0.09, 0.09, ..., 0.10, 0.05]
#  [0.24, 0.09, ..., 0.12, 0.04]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.09, ..., 0.07, 0.11]
#  [0.00, 0.00, ..., 0.11, 0.14]
#  ...
#  [0.09, 0.09, ..., 0.10, 0.05]
#  [0.24, 0.09, ..., 0.12, 0.04]]>
# root - DEBUG - 29-Dec-23 23:04:44 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.09, ..., 0.07, 0.11]
#  [0.00, 0.00, ..., 0.44, 0.56]
#  ...
#  [0.09, 0.09, ..., 0.10, 0.05]
#  [0.24, 0.09, ..., 0.12, 0.04]]>
# root - DEBUG - 29-Dec-23 23:04:44 - Sampling token iteration 10, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.07, ..., 0.09, 0.11]
#  [0.06, 0.06, ..., 0.05, 0.26]
#  ...
#  [0.09, 0.10, ..., 0.10, 0.09]
#  [0.05, 0.16, ..., 0.05, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.07, ..., 0.09, 0.11]
#  [0.00, 0.00, ..., 0.05, 0.26]
#  ...
#  [0.09, 0.10, ..., 0.10, 0.09]
#  [0.05, 0.16, ..., 0.05, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.07, ..., 0.09, 0.11]
#  [0.00, 0.00, ..., 0.16, 0.84]
#  ...
#  [0.09, 0.10, ..., 0.10, 0.09]
#  [0.05, 0.16, ..., 0.05, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 11, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.14, ..., 0.13, 0.09]
#  [0.16, 0.08, ..., 0.11, 0.19]
#  ...
#  [0.15, 0.04, ..., 0.16, 0.08]
#  [0.08, 0.14, ..., 0.09, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.13, 0.09]
#  [0.00, 0.00, ..., 0.11, 0.19]
#  ...
#  [0.00, 0.00, ..., 0.16, 0.08]
#  [0.08, 0.14, ..., 0.09, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.58, 0.42]
#  [0.00, 0.00, ..., 0.37, 0.63]
#  ...
#  [0.00, 0.00, ..., 0.67, 0.33]
#  [0.08, 0.14, ..., 0.09, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 12, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.20, 0.09, ..., 0.08, 0.06]
#  [0.15, 0.09, ..., 0.08, 0.15]
#  ...
#  [0.08, 0.04, ..., 0.04, 0.21]
#  [0.10, 0.13, ..., 0.13, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.08, 0.06]
#  [0.00, 0.00, ..., 0.08, 0.15]
#  ...
#  [0.00, 0.00, ..., 0.04, 0.21]
#  [0.10, 0.13, ..., 0.13, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.57, 0.43]
#  [0.00, 0.00, ..., 0.33, 0.67]
#  ...
#  [0.00, 0.00, ..., 0.15, 0.85]
#  [0.10, 0.13, ..., 0.13, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 13, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.13, ..., 0.15, 0.07]
#  [0.10, 0.21, ..., 0.14, 0.07]
#  ...
#  [0.05, 0.15, ..., 0.05, 0.12]
#  [0.08, 0.09, ..., 0.08, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.15, 0.07]
#  [0.00, 0.00, ..., 0.14, 0.07]
#  ...
#  [0.00, 0.00, ..., 0.05, 0.12]
#  [0.00, 0.00, ..., 0.08, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.69, 0.31]
#  [0.00, 0.00, ..., 0.66, 0.34]
#  ...
#  [0.00, 0.00, ..., 0.29, 0.71]
#  [0.00, 0.00, ..., 0.55, 0.45]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 14, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.08, ..., 0.15, 0.13]
#  [0.14, 0.07, ..., 0.15, 0.09]
#  ...
#  [0.18, 0.11, ..., 0.19, 0.04]
#  [0.07, 0.08, ..., 0.14, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.15, 0.13]
#  [0.00, 0.00, ..., 0.15, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.19, 0.04]
#  [0.00, 0.00, ..., 0.14, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.54, 0.46]
#  [0.00, 0.00, ..., 0.63, 0.37]
#  ...
#  [0.00, 0.00, ..., 0.84, 0.16]
#  [0.00, 0.00, ..., 0.62, 0.38]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Debugging, object=SymbolicLoss, rewards=tf.Tensor(
# [0.6648857  0.59967285 0.06033494 0.5402226  0.6025597  0.14516413
#  0.65225255 0.6061777  0.00355592 0.42210272 0.47952846 0.66488487], shape=(12,), dtype=float32), threshold=0.6636216342449188, mask=tf.Tensor([ True False False False False False False False False False False  True], shape=(12,), dtype=bool)
# root - DEBUG - 29-Dec-23 23:04:45 - Debugging, object=SymbolicLoss, risk_seeking=tf.Tensor(-0.03615409, shape=(), dtype=float32), entropy_loss=tf.Tensor(26.476463, shape=(), dtype=float32)
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 0, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.07, ..., 0.04, 0.09]
#  [0.10, 0.07, ..., 0.04, 0.09]
#  ...
#  [0.10, 0.07, ..., 0.04, 0.09]
#  [0.10, 0.07, ..., 0.04, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.07, ..., 0.00, 0.00]
#  [0.10, 0.07, ..., 0.00, 0.00]
#  ...
#  [0.10, 0.07, ..., 0.00, 0.00]
#  [0.10, 0.07, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.08, ..., 0.00, 0.00]
#  [0.12, 0.08, ..., 0.00, 0.00]
#  ...
#  [0.12, 0.08, ..., 0.00, 0.00]
#  [0.12, 0.08, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 1, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.10, ..., 0.21, 0.05]
#  [0.09, 0.13, ..., 0.18, 0.05]
#  ...
#  [0.07, 0.09, ..., 0.21, 0.06]
#  [0.09, 0.10, ..., 0.21, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.10, ..., 0.00, 0.05]
#  [0.09, 0.13, ..., 0.18, 0.05]
#  ...
#  [0.07, 0.09, ..., 0.21, 0.06]
#  [0.09, 0.10, ..., 0.00, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.13, ..., 0.00, 0.07]
#  [0.09, 0.13, ..., 0.18, 0.05]
#  ...
#  [0.07, 0.09, ..., 0.21, 0.06]
#  [0.12, 0.13, ..., 0.00, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 2, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.10, ..., 0.04, 0.09]
#  [0.07, 0.15, ..., 0.04, 0.08]
#  ...
#  [0.09, 0.10, ..., 0.07, 0.12]
#  [0.08, 0.08, ..., 0.04, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.10, ..., 0.00, 0.09]
#  [0.07, 0.15, ..., 0.00, 0.08]
#  ...
#  [0.09, 0.10, ..., 0.07, 0.12]
#  [0.08, 0.08, ..., 0.04, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.10, ..., 0.00, 0.09]
#  [0.07, 0.16, ..., 0.00, 0.08]
#  ...
#  [0.09, 0.10, ..., 0.07, 0.12]
#  [0.08, 0.08, ..., 0.04, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 3, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.09, ..., 0.14, 0.07]
#  [0.08, 0.13, ..., 0.18, 0.05]
#  ...
#  [0.10, 0.09, ..., 0.13, 0.10]
#  [0.08, 0.10, ..., 0.13, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.09, ..., 0.00, 0.07]
#  [0.08, 0.13, ..., 0.00, 0.05]
#  ...
#  [0.10, 0.09, ..., 0.13, 0.10]
#  [0.08, 0.10, ..., 0.13, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.11, ..., 0.00, 0.08]
#  [0.10, 0.16, ..., 0.00, 0.06]
#  ...
#  [0.10, 0.09, ..., 0.13, 0.10]
#  [0.08, 0.10, ..., 0.13, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 4, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.06, ..., 0.16, 0.08]
#  [0.12, 0.08, ..., 0.16, 0.09]
#  ...
#  [0.12, 0.07, ..., 0.10, 0.13]
#  [0.12, 0.10, ..., 0.19, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.06, ..., 0.16, 0.08]
#  [0.12, 0.08, ..., 0.00, 0.09]
#  ...
#  [0.12, 0.07, ..., 0.10, 0.13]
#  [0.12, 0.10, ..., 0.19, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.06, ..., 0.16, 0.08]
#  [0.14, 0.09, ..., 0.00, 0.11]
#  ...
#  [0.12, 0.07, ..., 0.10, 0.13]
#  [0.12, 0.10, ..., 0.19, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 5, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.06, ..., 0.05, 0.19]
#  [0.07, 0.10, ..., 0.05, 0.13]
#  ...
#  [0.05, 0.13, ..., 0.08, 0.10]
#  [0.16, 0.11, ..., 0.06, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.06, ..., 0.05, 0.19]
#  [0.07, 0.10, ..., 0.05, 0.13]
#  ...
#  [0.05, 0.13, ..., 0.08, 0.10]
#  [0.16, 0.11, ..., 0.06, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.06, ..., 0.05, 0.19]
#  [0.07, 0.10, ..., 0.05, 0.13]
#  ...
#  [0.05, 0.13, ..., 0.08, 0.10]
#  [0.16, 0.11, ..., 0.06, 0.10]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 6, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.04, ..., 0.07, 0.12]
#  [0.14, 0.05, ..., 0.15, 0.11]
#  ...
#  [0.12, 0.05, ..., 0.13, 0.12]
#  [0.13, 0.11, ..., 0.22, 0.03]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.04, ..., 0.07, 0.12]
#  [0.14, 0.05, ..., 0.15, 0.11]
#  ...
#  [0.12, 0.05, ..., 0.13, 0.12]
#  [0.13, 0.11, ..., 0.22, 0.03]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.04, ..., 0.07, 0.12]
#  [0.14, 0.05, ..., 0.15, 0.11]
#  ...
#  [0.12, 0.05, ..., 0.13, 0.12]
#  [0.13, 0.11, ..., 0.22, 0.03]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 7, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.05, 0.08, ..., 0.05, 0.12]
#  [0.05, 0.12, ..., 0.05, 0.11]
#  ...
#  [0.06, 0.10, ..., 0.09, 0.13]
#  [0.10, 0.10, ..., 0.08, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.05, 0.08, ..., 0.05, 0.12]
#  [0.05, 0.12, ..., 0.05, 0.11]
#  ...
#  [0.06, 0.10, ..., 0.09, 0.13]
#  [0.10, 0.10, ..., 0.08, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.05, 0.08, ..., 0.05, 0.12]
#  [0.05, 0.12, ..., 0.05, 0.11]
#  ...
#  [0.06, 0.10, ..., 0.09, 0.13]
#  [0.10, 0.10, ..., 0.08, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 8, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.10, ..., 0.11, 0.07]
#  [0.13, 0.08, ..., 0.12, 0.08]
#  ...
#  [0.17, 0.06, ..., 0.15, 0.13]
#  [0.12, 0.11, ..., 0.05, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.10, ..., 0.11, 0.07]
#  [0.13, 0.08, ..., 0.12, 0.08]
#  ...
#  [0.17, 0.06, ..., 0.15, 0.13]
#  [0.12, 0.11, ..., 0.05, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.11, 0.10, ..., 0.11, 0.07]
#  [0.13, 0.08, ..., 0.12, 0.08]
#  ...
#  [0.17, 0.06, ..., 0.15, 0.13]
#  [0.12, 0.11, ..., 0.05, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:45 - Sampling token iteration 9, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:45 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.18, 0.06, ..., 0.12, 0.03]
#  [0.11, 0.06, ..., 0.22, 0.09]
#  ...
#  [0.11, 0.08, ..., 0.08, 0.13]
#  [0.11, 0.09, ..., 0.21, 0.02]]>
# root - DEBUG - 29-Dec-23 23:04:46 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.18, 0.06, ..., 0.12, 0.03]
#  [0.11, 0.06, ..., 0.22, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.08, 0.13]
#  [0.11, 0.09, ..., 0.21, 0.02]]>
# root - DEBUG - 29-Dec-23 23:04:46 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.18, 0.06, ..., 0.12, 0.03]
#  [0.11, 0.06, ..., 0.22, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.38, 0.62]
#  [0.11, 0.09, ..., 0.21, 0.02]]>
# root - DEBUG - 29-Dec-23 23:04:46 - Sampling token iteration 10, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:46 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.11, ..., 0.07, 0.06]
#  [0.14, 0.08, ..., 0.14, 0.11]
#  ...
#  [0.06, 0.20, ..., 0.09, 0.14]
#  [0.09, 0.08, ..., 0.06, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:46 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.11, ..., 0.07, 0.06]
#  [0.14, 0.08, ..., 0.14, 0.11]
#  ...
#  [0.00, 0.00, ..., 0.09, 0.14]
#  [0.00, 0.00, ..., 0.06, 0.07]]>
# ...
# [[0.08, 0.07, ..., 0.10, 0.06]
#  [0.05, 0.08, ..., 0.04, 0.08]
#  ...
#  [0.10, 0.10, ..., 0.12, 0.12]
#  [0.08, 0.07, ..., 0.10, 0.04]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.10, 0.06]
#  [0.00, 0.00, ..., 0.04, 0.08]
#  ...
#  [0.00, 0.00, ..., 0.12, 0.12]
#  [0.00, 0.00, ..., 0.10, 0.04]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.61, 0.39]
#  [0.00, 0.00, ..., 0.35, 0.65]
#  ...
#  [0.00, 0.00, ..., 0.50, 0.50]
#  [0.00, 0.00, ..., 0.72, 0.28]]>
# root - DEBUG - 29-Dec-23 23:04:51 - Sampling token iteration 13, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:51 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.13, 0.10, ..., 0.09, 0.04]
#  [0.07, 0.08, ..., 0.12, 0.09]
#  ...
#  [0.16, 0.06, ..., 0.09, 0.09]
#  [0.04, 0.07, ..., 0.07, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.00, 0.04]
#  [0.00, 0.00, ..., 0.12, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.09, 0.09]
#  [0.00, 0.00, ..., 0.07, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.00, 1.00]
#  [0.00, 0.00, ..., 0.57, 0.43]
#  ...
#  [0.00, 0.00, ..., 0.49, 0.51]
#  [0.00, 0.00, ..., 0.37, 0.63]]>
# root - DEBUG - 29-Dec-23 23:04:51 - Sampling token iteration 14, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:51 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.13, 0.05, ..., 0.20, 0.04]
#  [0.20, 0.04, ..., 0.14, 0.06]
#  ...
#  [0.11, 0.08, ..., 0.14, 0.05]
#  [0.14, 0.04, ..., 0.07, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.20, 0.04]
#  [0.00, 0.00, ..., 0.14, 0.06]
#  ...
#  [0.00, 0.00, ..., 0.14, 0.05]
#  [0.00, 0.00, ..., 0.07, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.83, 0.17]
#  [0.00, 0.00, ..., 0.68, 0.32]
#  ...
#  [0.00, 0.00, ..., 0.75, 0.25]
#  [0.00, 0.00, ..., 0.44, 0.56]]>
# root - DEBUG - 29-Dec-23 23:04:51 - Debugging, object=SymbolicLoss, rewards=tf.Tensor(
# [0.01345562 0.60056186 0.48158193 0.45883307 0.46027988 0.01792387
#  0.29962    0.37310925 0.38420853 0.60307264 0.13574146 0.4487478 ], shape=(12,), dtype=float32), threshold=0.5886638641357422, mask=tf.Tensor([False  True False False False False False False False  True False False], shape=(12,), dtype=bool)
# root - DEBUG - 29-Dec-23 23:04:51 - Debugging, object=SymbolicLoss, risk_seeking=tf.Tensor(-0.28192863, shape=(), dtype=float32), entropy_loss=tf.Tensor(19.637157, shape=(), dtype=float32)
# root - DEBUG - 29-Dec-23 23:04:51 - Sampling token iteration 0, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:51 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.05, ..., 0.03, 0.08]
#  [0.08, 0.05, ..., 0.03, 0.08]
#  ...
#  [0.08, 0.05, ..., 0.03, 0.08]
#  [0.08, 0.05, ..., 0.03, 0.08]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.05, ..., 0.00, 0.00]
#  [0.08, 0.05, ..., 0.00, 0.00]
#  ...
#  [0.08, 0.05, ..., 0.00, 0.00]
#  [0.08, 0.05, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.05, ..., 0.00, 0.00]
#  [0.09, 0.05, ..., 0.00, 0.00]
#  ...
#  [0.09, 0.05, ..., 0.00, 0.00]
#  [0.09, 0.05, ..., 0.00, 0.00]]>
# root - DEBUG - 29-Dec-23 23:04:51 - Sampling token iteration 1, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:51 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.09, ..., 0.24, 0.05]
#  [0.09, 0.09, ..., 0.25, 0.04]
#  ...
#  [0.09, 0.09, ..., 0.25, 0.04]
#  [0.09, 0.09, ..., 0.25, 0.04]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.09, ..., 0.00, 0.05]
#  [0.09, 0.09, ..., 0.00, 0.04]
#  ...
#  [0.09, 0.09, ..., 0.00, 0.04]
#  [0.09, 0.09, ..., 0.00, 0.04]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.12, ..., 0.00, 0.07]
#  [0.12, 0.12, ..., 0.00, 0.06]
#  ...
#  [0.12, 0.12, ..., 0.00, 0.06]
#  [0.12, 0.12, ..., 0.00, 0.06]]>
# root - DEBUG - 29-Dec-23 23:04:51 - Sampling token iteration 2, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:51 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.05, ..., 0.05, 0.09]
#  [0.05, 0.09, ..., 0.02, 0.07]
#  ...
#  [0.05, 0.08, ..., 0.03, 0.09]
#  [0.05, 0.09, ..., 0.02, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.05, ..., 0.05, 0.09]
#  [0.05, 0.09, ..., 0.02, 0.07]
#  ...
#  [0.05, 0.08, ..., 0.00, 0.09]
#  [0.05, 0.09, ..., 0.02, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.10, 0.05, ..., 0.05, 0.09]
#  [0.05, 0.09, ..., 0.02, 0.07]
#  ...
#  [0.05, 0.09, ..., 0.00, 0.09]
#  [0.05, 0.09, ..., 0.02, 0.07]]>
# root - DEBUG - 29-Dec-23 23:04:51 - Sampling token iteration 3, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:51 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.06, ..., 0.13, 0.10]
#  [0.10, 0.10, ..., 0.25, 0.05]
#  ...
#  [0.12, 0.10, ..., 0.25, 0.06]
#  [0.06, 0.10, ..., 0.21, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.06, ..., 0.13, 0.10]
#  [0.10, 0.10, ..., 0.25, 0.05]
#  ...
#  [0.12, 0.10, ..., 0.00, 0.06]
#  [0.06, 0.10, ..., 0.21, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.06, ..., 0.13, 0.10]
#  [0.10, 0.10, ..., 0.25, 0.05]
#  ...
#  [0.15, 0.13, ..., 0.00, 0.08]
#  [0.06, 0.10, ..., 0.21, 0.05]]>
# root - DEBUG - 29-Dec-23 23:04:51 - Sampling token iteration 4, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:51 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.09, ..., 0.20, 0.08]
#  [0.09, 0.06, ..., 0.10, 0.11]
#  ...
#  [0.14, 0.08, ..., 0.14, 0.06]
#  [0.12, 0.07, ..., 0.16, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:51 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.09, ..., 0.20, 0.08]
#  [0.09, 0.06, ..., 0.10, 0.11]
#  ...
#  [0.14, 0.08, ..., 0.14, 0.06]
#  [0.12, 0.07, ..., 0.16, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.09, ..., 0.20, 0.08]
#  [0.09, 0.06, ..., 0.10, 0.11]
#  ...
#  [0.14, 0.08, ..., 0.14, 0.06]
#  [0.12, 0.07, ..., 0.16, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 5, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.09, ..., 0.08, 0.10]
#  [0.04, 0.09, ..., 0.05, 0.11]
#  ...
#  [0.06, 0.07, ..., 0.03, 0.12]
#  [0.11, 0.09, ..., 0.06, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.09, ..., 0.08, 0.10]
#  [0.04, 0.09, ..., 0.05, 0.11]
#  ...
#  [0.06, 0.07, ..., 0.03, 0.12]
#  [0.11, 0.09, ..., 0.06, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.14, 0.09, ..., 0.08, 0.10]
#  [0.04, 0.09, ..., 0.05, 0.11]
#  ...
#  [0.06, 0.07, ..., 0.03, 0.12]
#  [0.11, 0.09, ..., 0.06, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 6, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.18, 0.06, ..., 0.12, 0.09]
#  [0.15, 0.06, ..., 0.22, 0.09]
#  ...
#  [0.10, 0.08, ..., 0.17, 0.05]
#  [0.09, 0.06, ..., 0.15, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.18, 0.06, ..., 0.12, 0.09]
#  [0.15, 0.06, ..., 0.22, 0.09]
#  ...
#  [0.10, 0.08, ..., 0.17, 0.05]
#  [0.09, 0.06, ..., 0.15, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.18, 0.06, ..., 0.12, 0.09]
#  [0.15, 0.06, ..., 0.22, 0.09]
#  ...
#  [0.10, 0.08, ..., 0.17, 0.05]
#  [0.09, 0.06, ..., 0.15, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 7, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.04, 0.15, ..., 0.05, 0.10]
#  [0.06, 0.09, ..., 0.04, 0.07]
#  ...
#  [0.06, 0.09, ..., 0.05, 0.07]
#  [0.06, 0.08, ..., 0.10, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.04, 0.15, ..., 0.05, 0.10]
#  [0.06, 0.09, ..., 0.00, 0.07]
#  ...
#  [0.06, 0.09, ..., 0.05, 0.07]
#  [0.06, 0.08, ..., 0.10, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.04, 0.15, ..., 0.05, 0.10]
#  [0.07, 0.09, ..., 0.00, 0.07]
#  ...
#  [0.06, 0.09, ..., 0.05, 0.07]
#  [0.06, 0.08, ..., 0.10, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 8, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.08, ..., 0.10, 0.06]
#  [0.06, 0.11, ..., 0.14, 0.08]
#  ...
#  [0.09, 0.10, ..., 0.26, 0.03]
#  [0.23, 0.05, ..., 0.20, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.08, ..., 0.10, 0.06]
#  [0.06, 0.11, ..., 0.14, 0.08]
#  ...
#  [0.09, 0.10, ..., 0.26, 0.03]
#  [0.23, 0.05, ..., 0.20, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.09, 0.08, ..., 0.10, 0.06]
#  [0.06, 0.11, ..., 0.14, 0.08]
#  ...
#  [0.09, 0.10, ..., 0.26, 0.03]
#  [0.23, 0.05, ..., 0.20, 0.12]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 9, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.07, ..., 0.27, 0.04]
#  [0.12, 0.08, ..., 0.10, 0.08]
#  ...
#  [0.09, 0.04, ..., 0.08, 0.05]
#  [0.09, 0.06, ..., 0.07, 0.15]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.07, ..., 0.27, 0.04]
#  [0.12, 0.08, ..., 0.10, 0.08]
#  ...
#  [0.09, 0.04, ..., 0.00, 0.05]
#  [0.09, 0.06, ..., 0.07, 0.15]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.07, ..., 0.27, 0.04]
#  [0.12, 0.08, ..., 0.10, 0.08]
#  ...
#  [0.10, 0.05, ..., 0.00, 0.05]
#  [0.09, 0.06, ..., 0.07, 0.15]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 10, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.07, ..., 0.03, 0.11]
#  [0.09, 0.13, ..., 0.07, 0.08]
#  ...
#  [0.05, 0.07, ..., 0.03, 0.09]
#  [0.07, 0.09, ..., 0.13, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.07, ..., 0.03, 0.11]
#  [0.09, 0.13, ..., 0.07, 0.08]
#  ...
#  [0.05, 0.07, ..., 0.03, 0.09]
#  [0.07, 0.09, ..., 0.13, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.06, 0.07, ..., 0.03, 0.11]
#  [0.09, 0.13, ..., 0.07, 0.08]
#  ...
#  [0.05, 0.07, ..., 0.03, 0.09]
#  [0.07, 0.09, ..., 0.13, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 11, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.06, ..., 0.19, 0.08]
#  [0.10, 0.11, ..., 0.19, 0.06]
#  ...
#  [0.12, 0.09, ..., 0.18, 0.03]
#  [0.12, 0.10, ..., 0.33, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.19, 0.08]
#  [0.10, 0.11, ..., 0.19, 0.06]
#  ...
#  [0.00, 0.00, ..., 0.18, 0.03]
#  [0.12, 0.10, ..., 0.33, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.71, 0.29]
#  [0.10, 0.11, ..., 0.19, 0.06]
#  ...
#  [0.00, 0.00, ..., 0.87, 0.13]
#  [0.12, 0.10, ..., 0.33, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 12, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.08, 0.07, ..., 0.05, 0.08]
#  [0.08, 0.10, ..., 0.06, 0.13]
#  ...
#  [0.12, 0.06, ..., 0.07, 0.03]
#  [0.14, 0.04, ..., 0.06, 0.15]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.05, 0.08]
#  [0.08, 0.10, ..., 0.06, 0.13]
#  ...
#  [0.00, 0.00, ..., 0.07, 0.03]
#  [0.00, 0.00, ..., 0.06, 0.15]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.40, 0.60]
#  [0.08, 0.10, ..., 0.06, 0.13]
#  ...
#  [0.00, 0.00, ..., 0.68, 0.32]
#  [0.00, 0.00, ..., 0.28, 0.72]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 13, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.07, 0.08, ..., 0.08, 0.07]
#  [0.13, 0.10, ..., 0.11, 0.12]
#  ...
#  [0.08, 0.11, ..., 0.07, 0.04]
#  [0.10, 0.08, ..., 0.21, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.08, 0.07]
#  [0.13, 0.10, ..., 0.11, 0.12]
#  ...
#  [0.00, 0.00, ..., 0.07, 0.04]
#  [0.00, 0.00, ..., 0.21, 0.09]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.53, 0.47]
#  [0.13, 0.10, ..., 0.11, 0.12]
#  ...
#  [0.00, 0.00, ..., 0.65, 0.35]
#  [0.00, 0.00, ..., 0.70, 0.30]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Sampling token iteration 14, object=RNNSampler
# root - DEBUG - 29-Dec-23 23:04:52 - Probs before constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.12, 0.04, ..., 0.12, 0.06]
#  [0.08, 0.13, ..., 0.09, 0.09]
#  ...
#  [0.07, 0.07, ..., 0.16, 0.04]
#  [0.13, 0.07, ..., 0.21, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After constraints, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.12, 0.06]
#  [0.08, 0.13, ..., 0.09, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.16, 0.04]
#  [0.00, 0.00, ..., 0.21, 0.14]]>
# root - DEBUG - 29-Dec-23 23:04:52 - After normalization, object=RNNSampler, func=call, probs=<Tensor shape: (12, 10)
# [[0.00, 0.00, ..., 0.68, 0.32]
#  [0.08, 0.13, ..., 0.09, 0.09]
#  ...
#  [0.00, 0.00, ..., 0.78, 0.22]
#  [0.00, 0.00, ..., 0.60, 0.40]]>
# root - DEBUG - 29-Dec-23 23:04:52 - Debugging, object=SymbolicLoss, rewards=tf.Tensor(
# [0.56396884 0.4770464  0.5582362  0.48419815 0.4961948  0.12328871
#  0.4647072  0.58531845 0.42491314 0.5036593  0.65982956 0.32134885], shape=(12,), dtype=float32), threshold=0.5831834852695466, mask=tf.Tensor([False False False False False False False  True False False  True False], shape=(12,), dtype=bool)
# root - DEBUG - 29-Dec-23 23:04:52 - Debugging, object=SymbolicLoss, risk_seeking=tf.Tensor(-0.9365411, shape=(), dtype=float32), entropy_loss=tf.Tensor(25.642796, shape=(), dtype=float32)

# %%
rewards[0]
# Out:
# <tf.Tensor: shape=(12,), dtype=float32, numpy=
# array([0.58211213, 0.01164853, 0.        , 0.32887483, 0.6278294 ,
#        0.5896761 , 0.6418639 , 0.46759215, 0.05056982, 0.55055565,
#        0.54626274, 0.48419815], dtype=float32)>

# %%
expression = results.expressions[4]

# %%
expression.tree.left_child.left_child.left_child.left_child.left_child.left_child

# %%
def plot_expresion(expression, x):
    trace = go.Scatter(x=x["var_x"], y=expression.eval(x).numpy())
    return go.Figure(
        [
            trace,
            go.Scatter(
                x=x["var_x"], y=y, line=dict(dash="dash", color=trace.marker.color)
            ),
        ]
    )

# %%
plot_expresion(expression, x)

# %%
expression.eval(X)
